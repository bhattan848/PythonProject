# %%
from bs4 import BeautifulSoup
import requests
soup = BeautifulSoup('http://www.nepalstock.com/floorsheet', 'html.parser')
url = requests.get(soup)
source = url.text
source_code= BeautifulSoup(source, "lxml")
tag = source_code.table
tags = tag.find_all('tr')
#print(tags)
data = []
for i in tags:
    x = i.text
    data.append(x)
data
# del tags[0:1]
final_data = []
for j in data:
    final_data.append(j.split('\n'))
print(final_data)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\bs4\__init__.py:431: MarkupResemblesLocatorWarning: "http://www.nepalstock.com/floorsheet" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# [['', '', '', 'Contract No.\xa0  |', '', '', 'Stock Symbol', '... ...  |', '                ', 'Buyer\xa0  |', 'Seller\xa0  |', 'Total Rows', '                    ', '20', '50', '200', '300', '500', ' |', '                ', '', '', '', '', ''], ['', 'S.N.', 'Contract No', 'Stock Symbol', 'Buyer Broker', 'Seller Broker', 'Quantity', 'Rate', 'Amount', ''], ['', '1', '2022032401007148', 'NICA', '28', '58', '706', '780', '550680.00', ''], ['', '2', '2022032401007147', 'NICA', '28', '35', '1042', '778', '810676.00', ''], ['', '3', '2022032401007146', 'NICA', '28', '6', '50', '777', '38850.00', ''], ['', '4', '2022032401007145', 'NICA', '28', '25', '78', '775', '60450.00', ''], ['', '5', '2022032401007144', 'NICA', '28', '41', '60', '775', '46500.00', ''], ['', '6', '2022032401007143', 'NICA', '28', '42', '327', '775', '253425.00', ''], ['', '7', '2022032401007142', 'NICA', '28', '58', '17', '775', '13175.00', ''], ['', '8', '2022032401007141', 'NICA', '28', '51', '220', '773.5', '170170.00', ''], ['', '9', '2022032401007140', 'NICA', '28', '1', '600', '773', '463800.00', ''], ['', '10', '2022032401007139', 'NICA', '28', '1', '400', '771', '308400.00', ''], ['', '11', '2022032404012411', 'GHL', '38', '58', '195', '323', '62985.00', ''], ['', '12', '2022032404012410', 'GHL', '38', '45', '500', '322', '161000.00', ''], ['', '13', '2022032404012409', 'GHL', '38', '14', '20', '322', '6440.00', ''], ['', '14', '2022032404012408', 'GHL', '38', '42', '100', '320', '32000.00', ''], ['', '15', '2022032403017286', 'NRIC', '22', '38', '20', '1185', '23700.00', ''], ['', '16', '2022032404012407', 'GHL', '38', '4', '85', '320', '27200.00', ''], ['', '17', '2022032404012406', 'GHL', '38', '45', '100', '320', '32000.00', ''], ['', '18', '2022032403017285', 'NRIC', '48', '38', '30', '1185', '35550.00', ''], ['', '19', '2022032403017284', 'NRIC', '57', '38', '250', '1185', '296250.00', ''], ['', '20', '2022032404012405', 'HURJA', '38', '45', '20', '459.9', '9198.00', ''], ['', 'Page 1/2254\xa012345678910Next›Last»', ''], ['', 'Total Amount Rs.', '3,248,943,825', ''], ['', 'Total Quantity', '5,298,543', '']]

# %%
# del final_data[1:9]

# %%
del final_data[-1:-2:-1]

# %%
print(final_data)
# Out:
# [['', '', '', 'Contract No.\xa0  |', '', '', 'Stock Symbol', '... ...  |', '                ', 'Buyer\xa0  |', 'Seller\xa0  |', 'Total Rows', '                    ', '20', '50', '200', '300', '500', ' |', '                ', '', '', '', '', ''], ['', 'S.N.', 'Contract No', 'Stock Symbol', 'Buyer Broker', 'Seller Broker', 'Quantity', 'Rate', 'Amount', ''], ['', '1', '2022032401007148', 'NICA', '28', '58', '706', '780', '550680.00', ''], ['', '2', '2022032401007147', 'NICA', '28', '35', '1042', '778', '810676.00', ''], ['', '3', '2022032401007146', 'NICA', '28', '6', '50', '777', '38850.00', ''], ['', '4', '2022032401007145', 'NICA', '28', '25', '78', '775', '60450.00', ''], ['', '5', '2022032401007144', 'NICA', '28', '41', '60', '775', '46500.00', ''], ['', '6', '2022032401007143', 'NICA', '28', '42', '327', '775', '253425.00', ''], ['', '7', '2022032401007142', 'NICA', '28', '58', '17', '775', '13175.00', ''], ['', '8', '2022032401007141', 'NICA', '28', '51', '220', '773.5', '170170.00', ''], ['', '9', '2022032401007140', 'NICA', '28', '1', '600', '773', '463800.00', ''], ['', '10', '2022032401007139', 'NICA', '28', '1', '400', '771', '308400.00', ''], ['', '11', '2022032404012411', 'GHL', '38', '58', '195', '323', '62985.00', ''], ['', '12', '2022032404012410', 'GHL', '38', '45', '500', '322', '161000.00', ''], ['', '13', '2022032404012409', 'GHL', '38', '14', '20', '322', '6440.00', ''], ['', '14', '2022032404012408', 'GHL', '38', '42', '100', '320', '32000.00', ''], ['', '15', '2022032403017286', 'NRIC', '22', '38', '20', '1185', '23700.00', ''], ['', '16', '2022032404012407', 'GHL', '38', '4', '85', '320', '27200.00', ''], ['', '17', '2022032404012406', 'GHL', '38', '45', '100', '320', '32000.00', ''], ['', '18', '2022032403017285', 'NRIC', '48', '38', '30', '1185', '35550.00', ''], ['', '19', '2022032403017284', 'NRIC', '57', '38', '250', '1185', '296250.00', ''], ['', '20', '2022032404012405', 'HURJA', '38', '45', '20', '459.9', '9198.00', ''], ['', 'Page 1/2254\xa012345678910Next›Last»', ''], ['', 'Total Amount Rs.', '3,248,943,825', '']]

# %%
import csv
f = open('nepse.csv','a')
x = csv.writer(f)
for i in final_data:
    x.writerow(i)

# %%
import pandas as pd
df = pd.read_csv('nepse.csv',encoding = 'ISO-8859-1')
df
# Out:
#     Unnamed: 0                         Unnamed: 1        Unnamed: 2  \
# 0          NaN                                  8  2022032401007141
# 1          NaN                                  9  2022032401007140
# 2          NaN                                 10  2022032401007139
# 3          NaN                                 11  2022032404012411
# 4          NaN                                 12  2022032404012410
# ..         ...                                ...               ...
# 74         NaN                                 17  2022032404012406
# 75         NaN                                 18  2022032403017285
# 76         NaN                                 19  2022032403017284
# 77         NaN                                 20  2022032404012405
# 78         NaN  Page 1/2254 12345678910NextLast»               NaN
#
#    Contract No.   |  Unnamed: 4  Unnamed: 5 Stock Symbol  \
# 0              NICA        28.0        51.0          220
# 1              NICA        28.0         1.0          600
# 2              NICA        28.0         1.0          400
# 3               GHL        38.0        58.0          195
# 4               GHL        38.0        45.0          500
# ..              ...         ...         ...          ...
# 74              GHL        38.0        45.0          100
# 75             NRIC        48.0        38.0           30
# 76             NRIC        57.0        38.0          250
# 77            HURJA        38.0        45.0           20
# 78              NaN         NaN         NaN          NaN
#
#    ... ...  |  \
# 0                                               773.5
# 1                                                 773
# 2                                                 771
# 3                                                 323
# 4                                                 322
# ..                                                ...
# 74                                                320
# 75                                               1185
# 76                                               1185
# 77                                              459.9
# 78                                                NaN
#
#                     Buyer   |  ... 200 300 500    |                  .1  \
# 0         170170.00       NaN  ... NaN NaN NaN  NaN                 NaN
# 1         463800.00       NaN  ... NaN NaN NaN  NaN                 NaN
# 2         308400.00       NaN  ... NaN NaN NaN  NaN                 NaN
# 3          62985.00       NaN  ... NaN NaN NaN  NaN                 NaN
# 4         161000.00       NaN  ... NaN NaN NaN  NaN                 NaN
# ..              ...       ...  ...  ..  ..  ..  ...                 ...
# 74         32000.00       NaN  ... NaN NaN NaN  NaN                 NaN
# 75         35550.00       NaN  ... NaN NaN NaN  NaN                 NaN
# 76        296250.00       NaN  ... NaN NaN NaN  NaN                 NaN
# 77          9198.00       NaN  ... NaN NaN NaN  NaN                 NaN
# 78              NaN       NaN  ... NaN NaN NaN  NaN                 NaN
#
#     Unnamed: 20  Unnamed: 21  Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0           NaN          NaN          NaN         NaN         NaN
# 1           NaN          NaN          NaN         NaN         NaN
# 2           NaN          NaN          NaN         NaN         NaN
# 3           NaN          NaN          NaN         NaN         NaN
# 4           NaN          NaN          NaN         NaN         NaN
# ..          ...          ...          ...         ...         ...
# 74          NaN          NaN          NaN         NaN         NaN
# 75          NaN          NaN          NaN         NaN         NaN
# 76          NaN          NaN          NaN         NaN         NaN
# 77          NaN          NaN          NaN         NaN         NaN
# 78          NaN          NaN          NaN         NaN         NaN
#
# [79 rows x 25 columns]
